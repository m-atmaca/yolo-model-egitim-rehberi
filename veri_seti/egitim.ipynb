# %% [markdown]
# güncelleme

# %%
# !apt-get update

# %%
# %cd /content/drive/MyDrive/darknet

# %%
# !sudo apt install dos2unix

# %%
# !find . -type f -print0 | xargs -0 dos2unix

# %%
# %cd darknet

# %%
# !chmod +x /content/drive/MyDrive/darknet

# %%
# !make

# %%
# !rm /content/drive/MyDrive/darknet/backup -r

# %%
# !ln -s /content/drive/MyDrive/YeniKlasor/backup /content/drive/MyDrive/darknet

# %%
# !./darknet detector train veri_seti/veri.data demoYolov4.cfg yolov4.conv.137 -map -dont_show
